# %% [markdown]
# <a href="https://colab.research.google.com/github/pragatisachan/ProjectChalenge1/blob/main/CREDIT_CARD_FRAUD_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv("/content/creditcard.csv")
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 45641  42436 -2.481639 -2.439949  0.363642  1.216827  2.572442 -1.264220
# 45642  42436  1.223475  0.014944  0.471312 -0.038410 -0.566793 -0.867970
# 45643  42436  1.258657  0.421016  0.325437  0.684259 -0.292529 -1.052786
# 45644  42437 -0.500147  1.000770  1.809639 -0.114551  0.333865 -0.577076
# 45645  42437 -0.652459  0.177290  1.955607 -1.879724 -0.368457       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 45641  42436 -2.481639 -2.439949  0.363642  1.216827  2.572442 -1.264220
# 45642  42436  1.223475  0.014944  0.471312 -0.038410 -0.566793 -0.867970
# 45643  42436  1.258657  0.421016  0.325437  0.684259 -0.292529 -1.052786
# 45644  42437 -0.500147  1.000770  1.809639 -0.114551  0.333865 -0.577076
# 45645  42437 -0.652459  0.177290  1.955607 -1.879724 -0.368457       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 45641  42436 -2.481639 -2.439949  0.363642  1.216827  2.572442 -1.264220
# 45642  42436  1.223475  0.014944  0.471312 -0.038410 -0.566793 -0.867970
# 45643  42436  1.258657  0.421016  0.325437  0.684259 -0.292529 -1.052786
# 45644  42437 -0.500147  1.000770  1.809639 -0.114551  0.333865 -0.577076
# 45645  42437 -0.652459  0.177290  1.955607 -1.879724 -0.368457       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 45641 -0.443652  0.075853  0.073188  ... -0.039426  0.480591  1.779358
# 45642 -0.058213 -0.144080  0.164904  ... -0.053292 -0.093680  0.106348
# 45643  0.145228 -0.253567 -0.100521  ... -0.278029 -0.757417  0.119613
# 45644  1.062325 -0.513050 -0.048285  ... -0.193814 -0.161410  0.036965
# 45645       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45646 entries, 0 to 45645
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    45646 non-null  int64
#  1   V1      45646 non-null  float64
#  2   V2      45646 non-null  float64
#  3   V3      45646 non-null  float64
#  4   V4      45646 non-null  float64
#  5   V5      45646 non-null  float64
#  6   V6      45645 non-null  float64
#  7   V7      45645 non-null  float64
#  8   V8      45645 non-null  float64
#  9   V9      45645 non-null  float64
#  10  V10     45645 non-null  float64
#  11  V11     45645 non-null  float64
#  12  V12     45645 non-null  float64
#  13  V13     45645 non-null  float64
#  14  V14     45645 non-null  float64
#  15  V15     45645 non-null  float64
#  16  V16     45645 non-null  float64
#  17  V17     45645 non-null  float64
#  18  V18     45645 non-null  float64
#  19  V19     45645 non-null  float64
# ...

# %% [markdown]
# # Checking the Number of missing values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0.0    45503
# 1.0      142
# Name: Class, dtype: int64

# %% [markdown]
# # Seprating the data for analysis

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %% [markdown]
# # Statistical measures of the data

# %%
legit.Amount.describe()
# Out:
# count    45503.000000
# mean        90.808470
# std        240.322652
# min          0.000000
# 25%          7.580000
# 50%         24.990000
# 75%         82.360000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     142.000000
# mean       97.592183
# std       233.185192
# min         0.000000
# 25%         1.000000
# 50%         8.370000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %% [markdown]
# # Compare the values for both transaction

# %%
df.groupby('Class').mean()
# Out:
#                Time       V1        V2         V3        V4        V5  \
# Class
# 0.0    27549.332857 -0.21371  0.011525   0.732168  0.173212 -0.230885
# 1.0    26193.556338 -7.87188  5.609155 -10.671851  6.067972 -5.862266
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.106122 -0.092498  0.041321  0.169777  ...  0.046284 -0.029987
# 1.0   -2.315720 -8.269674  3.901566 -3.650345  ...  0.486666  0.898581
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.108242 -0.038246  0.009637  0.136319  0.021863  0.003681  0.004547
# 1.0   -0.250143 -0.300033 -0.079930  0.257712  0.163858  0.596174  0.034797
#
#           Amount
# Class
# 0.0    90.808470
# 1.0    97.592183
#
# [2 rows x 30 columns]

# %% [markdown]
# # Under Sampling

# %%
legit_sample = legit.sample(n = 142)
print(legit_sample)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 19654  30437  1.349179 -0.455889  0.434875 -0.571828 -1.069183 -1.019754
# 1540    1210  1.311675 -0.050290  0.028650 -0.372548 -0.184031 -0.369014
# 20921  31356  0.615719 -1.466132  0.504072  0.871344 -1.563556 -0.453259
# 35620  38196 -1.037006  0.515577  1.957720  0.572507 -0.470927  1.417127
# 40077  40083 -0.908313 -0.159054  1.007995  1.350622 -1.030737  0.695669
# ...      ...       ...       ...       ...       ...       ...       ...
# 16461  27837  1.129631  0.068017  1.447302  1.407510 -1.027473 -0.356129
# 20263  30910  1.344975 -0.854111  0.479506 -1.052829 -0.747374  0.721624
# 6777    8535 -1.038477  0.591250  1.425730 -1.804925 -1.016605 -0.943998
# 14190  25223 -1.215059  0.125584 -0.387024  1.099118  0.322936 -0.594943
# 43224  41423  1.135954  0.274689  0.563478  0.992261 -0.202573 -0.213771
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %% [markdown]
# # Concatenating two dataframes

# %%
new_dataset = pd.concat([legit_sample , fraud] , axis = 0)
new_dataset.shape
# Out:
# (284, 31)

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    27219.253521 -0.269369 -0.137733   0.691123  0.229874 -0.375517
# 1.0    26193.556338 -7.871880  5.609155 -10.671851  6.067972 -5.862266
#
#             V6        V7        V8        V9  ...       V20       V21  \
# Class                                         ...
# 0.0   -0.00785 -0.111829 -0.073183  0.206115  ...  0.053312  0.075954
# 1.0   -2.31572 -8.269674  3.901566 -3.650345  ...  0.486666  0.898581
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.091223 -0.139813  0.051392  0.169532  0.011033  0.038667 -0.052304
# 1.0   -0.250143 -0.300033 -0.079930  0.257712  0.163858  0.596174  0.034797
#
#            Amount
# Class
# 0.0    118.421690
# 1.0     97.592183
#
# [2 rows x 30 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    142
# 1.0    142
# Name: Class, dtype: int64

# %% [markdown]
# # Spliting the data into features and target

# %%
X = new_dataset.drop(columns ='Class' , axis = 1)

# %%
y = new_dataset['Class']

# %% [markdown]
# # Split the data into training data

# %%
from sklearn.model_selection import train_test_split
X_train , X_test ,y_train , y_test = train_test_split(X , y , test_size = 0.2 , random_state = 26)
X_train.shape
# Out:
# (227, 30)

# %%
X_test.shape
# Out:
# (57, 30)

# %%
y_train.shape
# Out:
# (227,)

# %%
y_test.shape
# Out:
# (57,)

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# # Training the logistic regression model with training data

# %%
model.fit(X_train , y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_pred = model.predict(X_train)

# %%
X_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
training_data_accuracy = accuracy_score(X_train_pred , y_train)
print(training_data_accuracy)
# Out:
# 0.9779735682819384

# %%
testing_data_accuracy = accuracy_score(X_test_pred , y_test)
print(testing_data_accuracy)
# Out:
# 0.9473684210526315

# %% [markdown]
# # Get Future Prediction

# %%
df_new = df.sample(n=3)
df_new
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 21119  31480  1.505489 -0.572398 -1.732821 -1.828074  1.847776  2.903257
# 22520  32289  1.284377 -0.645486  0.496034 -0.612463 -0.825266 -0.011628
# 38186  39287  1.159093  0.338599  0.407067  1.147585 -0.197296 -0.665654
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 21119 -0.671467  0.607996 -1.229009  ...  0.182751  0.331239 -0.222024
# 22520 -0.675944  0.080061 -0.794847  ...  0.071842  0.299444 -0.034029
# 38186  0.203187 -0.153522 -0.138679  ...  0.089834  0.346656 -0.045539
#
#             V24       V25       V26       V27       V28  Amount  Class
# 21119  1.053871  0.974314 -0.023879 -0.022316 -0.004923   11.00    0.0
# 22520  0.061181  0.469566 -0.234946  0.028066  0.002944   22.04    0.0
# 38186  0.430161  0.588588 -0.322080  0.032797  0.023358   14.50    0.0
#
# [3 rows x 31 columns]

# %%
X_new = df_new.drop(columns = 'Class' , axis = 1)
X_new
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 21119  31480  1.505489 -0.572398 -1.732821 -1.828074  1.847776  2.903257
# 22520  32289  1.284377 -0.645486  0.496034 -0.612463 -0.825266 -0.011628
# 38186  39287  1.159093  0.338599  0.407067  1.147585 -0.197296 -0.665654
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 21119 -0.671467  0.607996 -1.229009  ...  0.184935  0.182751  0.331239
# 22520 -0.675944  0.080061 -0.794847  ...  0.086220  0.071842  0.299444
# 38186  0.203187 -0.153522 -0.138679  ... -0.125851  0.089834  0.346656
#
#             V23       V24       V25       V26       V27       V28  Amount
# 21119 -0.222024  1.053871  0.974314 -0.023879 -0.022316 -0.004923   11.00
# 22520 -0.034029  0.061181  0.469566 -0.234946  0.028066  0.002944   22.04
# 38186 -0.045539  0.430161  0.588588 -0.322080  0.032797  0.023358   14.50
#
# [3 rows x 30 columns]

# %%
y_new = df_new['Class']
y_new
# Out:
# 21119    0.0
# 22520    0.0
# 38186    0.0
# Name: Class, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_new = ss.fit_transform(X_new)

# %%
y_pred_new = model.predict(X_new)
y_pred_new
# Out:
# array([0., 0., 0.])
